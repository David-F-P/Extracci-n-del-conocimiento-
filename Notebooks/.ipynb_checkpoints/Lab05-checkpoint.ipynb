# %%
#Datos Sinteticos
#Utilizacion

# %%
import pandas as pd
import numpy as np
import random

# %%
#Importamos libreria Faker
from faker import Faker

# %%
pip install Faker
# Out:
# Requirement already satisfied: Faker in C:\Users\David\anaconda3\envs\ExtraccionDeBaseDeDatos9A\Lib\site-packages (40.21.0)
# Requirement already satisfied: tzdata in C:\Users\David\anaconda3\envs\ExtraccionDeBaseDeDatos9A\Lib\site-packages (from Faker) (2026.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
fake = Faker("es_MX")

# %%
datos = []
for i in range (100):
    datos.append(
        {
            "id_usuario": i +1,
            "nombre" : fake.name(),
            "correo" : fake.email(),
            "edad" : random.randint(18,65),
            "seguidores" : random.randint(50,5000),
            "plataforma" : random.choice(["TikTok","Instagram","Youtube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                                nombre  \
# 0            1  Guillermina Rosalia Alonzo Sepúlveda
# 1            2             Gilberto Zeferino Arreola
# 2            3               Ing. Mercedes Arredondo
# 3            4                        Sandra Fonseca
# 4            5                  Silvano Duarte Yáñez
# ..         ...                                   ...
# 95          96                  Sra. Francisca Rocha
# 96          97                   Diana Hilda Mercado
# 97          98                           Miriam Ríos
# 98          99                Srita. Perla Navarrete
# 99         100       Guillermo Ernesto Sevilla Reyes
#
#                          correo  edad  seguidores plataforma
# 0      valdezblanca@example.net    44         414     TikTok
# 1          silvia79@example.net    58        4356    Youtube
# 2           elozano@example.net    31         362    Youtube
# 3         psisneros@example.com    40        4494  Instagram
# 4      mercadonoemi@example.com    39        3010    Youtube
# ..                          ...   ...         ...        ...
# 95       zeferino28@example.org    34         536  Instagram
# 96     guevarajorge@example.net    65        2647    Youtube
# 97       biancarael@example.org    20        1275     TikTok
# 98  mauriciosanchez@example.net    21        4005  Instagram
# 99          ksotelo@example.net    56        4298    Youtube
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    object
#  2   correo      100 non-null    object
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   43.310000  2437.840000
# std     29.011492   13.704453  1443.031277
# min      1.000000   18.000000    94.000000
# 25%     25.750000   33.000000  1304.250000
# 50%     50.500000   43.000000  2382.500000
# 75%     75.250000   55.250000  3852.750000
# max    100.000000   65.000000  4951.000000

# %%
dfInfluencer.describe(include= "all")
# Out:
#         id_usuario                                nombre  \
# count   100.000000                                   100
# unique         NaN                                   100
# top            NaN  Guillermina Rosalia Alonzo Sepúlveda
# freq           NaN                                     1
# mean     50.500000                                   NaN
# std      29.011492                                   NaN
# min       1.000000                                   NaN
# 25%      25.750000                                   NaN
# 50%      50.500000                                   NaN
# 75%      75.250000                                   NaN
# max     100.000000                                   NaN
#
#                           correo        edad   seguidores plataforma
# count                        100  100.000000   100.000000        100
# unique                       100         NaN          NaN          3
# top     valdezblanca@example.net         NaN          NaN  Instagram
# freq                           1         NaN          NaN         36
# mean                         NaN   43.310000  2437.840000        NaN
# std                          NaN   13.704453  1443.031277        NaN
# min                          NaN   18.000000    94.000000        NaN
# 25%                          NaN   33.000000  1304.250000        NaN
# 50%                          NaN   43.000000  2382.500000        NaN
# 75%                          NaN   55.250000  3852.750000        NaN
# max                          NaN   65.000000  4951.000000        NaN

# %%
#Graficar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Graficamos como se generan las edades
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins =10)
plt.title("Distribucion de edades")
plt.show()

# %%
# Graficamos la cantidad de usuarios por plataforma
plt.figure(figsize=(8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()
